# %% [markdown]
# # Voting

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X, y = make_classification(
    n_samples = 500,
    n_features = 20,
    n_informative = 5,
    n_redundant = 2,
    random_state = 42
)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression()
svc = SVC()
dtc = DecisionTreeClassifier(max_depth=3)

# %%
voting_clf = VotingClassifier(
    estimators= [
        ("lr", lr),
        ("svc", svc),
        ("dtc", dtc)
    ]
)

# %%
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression()), ('svc', SVC()),
#                              ('dtc', DecisionTreeClassifier(max_depth=3))])

# %%
y_pred = voting_clf.predict(X_test)

print("accuracy - ", accuracy_score(y_pred, y_test))
print("cr - ", classification_report(y_pred, y_test))
# Out:
# accuracy -  0.8333333333333334
# cr -                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85        83
#            1       0.80      0.84      0.82        67
#
#     accuracy                           0.83       150
#    macro avg       0.83      0.83      0.83       150
# weighted avg       0.83      0.83      0.83       150

# %%
from sklearn.datasets import make_regression

X, y = make_regression(
    n_samples = 500,
    n_features = 20,
    n_informative = 5,
    random_state = 42
)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lin_reg = LinearRegression()
dtr = DecisionTreeRegressor(max_depth=3)
svr = SVR()

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(
    estimators = [
        ("lr", lin_reg),
        ("dtr", dtr),
        ("svr", svr)
    ]
)

# %%
vr.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor(max_depth=3)),
#                             ('svr', SVR())])

# %%
y_pred = vr.predict(X_test)

# %%
from sklearn.metrics import r2_score

print("r^2", r2_score(y_test, y_pred))
# Out:
# r^2 0.8090433289971101

# %% [markdown]
# # Stacking

# %%
# classifier
from sklearn.ensemble import StackingClassifier

# %%
meta_model = LogisticRegression()

stacking_clf = StackingClassifier(
    estimators= [
        ("lr", lr),
        ("svc", svc),
        ("dtc", dtc)
    ],
    final_estimator=meta_model,
    cv=5
)

# %%
stacking_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 stacking_clf.fit(X_train, y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = [
#      67     "{}={}".format(name, arg)
#      68     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      69 ]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:700, in StackingClassifier.fit(self, X, y, sample_weight, **fit_params)
#     665 """Fit the estimators.
#     666
#     667 Parameters
#    (...)
#     697     Returns a fitted instance of estimator.
#     698 """
#     699 _raise_for_params(fit_params, self, "fit")
# --> 700 check_classification_targets(y)
#     701 if type_of_target(y) == "multilabel-indicator":
#     702     self._label_encoder = [LabelEncoder().fit(yk) for yk in y.T]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:222, in check_classification_targets(y)
#     214 y_type = type_of_target(y, input_name="y")
#     215 if y_type not in [
#     216     "binary",
#     217     "multiclass",
#    (...)
#     220     "multilabel-sequences",
#     221 ]:
# --> 222     raise ValueError(
#     223         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224         "classifier, which expects discrete classes on a "
#     225         "regression target with continuous values."
#     226     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
y_pred = stacking_clf.predict(X_test)

print("accuracy, ", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y_pred = stacking_clf.predict(X_test)
#       3 print("accuracy, ", accuracy_score(y_test, y_pred))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:761, in StackingClassifier.predict(self, X, **predict_params)
#     758     routed_params.final_estimator_ = Bunch(predict={})
#     759     routed_params.final_estimator_.predict = predict_params
# --> 761 y_pred = super().predict(X, **routed_params.final_estimator_["predict"])
#     762 if isinstance(self._label_encoder, list):
#     763     # Handle the multilabel-indicator case
#     764     y_pred = np.array(
#     765         [
#     766             self._label_encoder[target_idx].inverse_transform(target)
#     767             for target_idx, target in enumerate(y_pred.T)
#     768         ]
#     769     ).T
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_stacking.py:373, in _BaseStacking.predict(self, X, **predict_params)
#     349 @available_if(
#     350     _estimator_has("predict", delegates=("final_estimator_", "final_estimator"))
#     351 )
#     352 def predict(self, X, **predict_params):
#     353     """Predict target for X.
#     354
#     355     Parameters
#    (...)
#     370         Predicted targets.
#     371     """
# --> 373     check_is_fitted(self)
#     374     return self.final_estimator_.predict(self.transform(X), **predict_params)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1757, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754     return
#    1756 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1757     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This StackingClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# classifier
from sklearn.ensemble import StackingRegressor

# %%
sr = StackingRegressor(
    estimators = [
        ("lr", lin_reg),
        ("dtr", dtr),
        ("svr", svr)
    ],
    cv=5
)

sr.fit(X_train, y_train)

# %%
y_pred = sr.predict(X_test)
y_pred_train = sr.predict(X_train)

print("r2 score test", r2_score(y_test, y_pred))
print("r2 score train", r2_score(y_train, y_pred_train))
